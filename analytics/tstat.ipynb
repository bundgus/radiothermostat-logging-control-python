# %%
import pandas as pd
from tpot import TPOTRegressor
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('tstat_log.csv')
data
# Out:
#                           log_timestamp ts1_fmode ts1_fstate ts1_hold  \
# 0      2017-08-09 03:07:27.432848+00:00      Auto        Off  Enabled
# 1      2017-08-09 03:12:58.455624+00:00      Auto        Off  Enabled
# 2      2017-08-09 03:18:27.968084+00:00      Auto        Off  Enabled
# 3      2017-08-09 03:23:57.327527+00:00      Auto         On  Enabled
# 4      2017-08-09 03:29:29.323964+00:00      Auto         On  Enabled
# 5      2017-08-09 03:34:57.039383+00:00      Auto        Off  Enabled
# 6      2017-08-09 03:40:34.651107+00:00      Auto        Off  Enabled
# 7      2017-08-09 03:46:05.322617+00:00      Auto        Off  Enabled
# 8      2017-08-09 03:51:39.227431+00:00      Auto        Off  Enabled
# 9      2017-08-09 03:57:08.928282+00:00      Auto        Off  Enabled
# 10     2017-08-09 04:02:37.866763+00:00      Auto        Off  Enabled
# 11     2017-08-09 04:08:07.544519+00:00      Auto        Off  Enabled
# 12     2017-08-09 04:13:37.365874+00:00      Auto         On  Enabled
# 13     2017-08-09 04:19:04.614592+00:00      Auto        Off  Enabled
# 14     2017-08-09 04:24:36.280590+00:00      Auto        Off  Enabled
# 15     2017-08-09 04:30:14.462519+00:00      Auto        Off  Enabled
# 16     2017-08-09 04:35:44.939866+00:00      Auto        Off  Enabled
# 17     2017-08-09 04:41:16.329350+00:00      Auto        Off  Enabled
# 18     2017-08-09 04:46:47.271982+00:00      Auto         On  Enabled
# 19     2017-08-09 04:52:23.416741+00:00      Auto         On  Enabled
# 20     2017-08-09 04:57:53.638374+00:00      Auto        Off  Enabled
# 21     2017-08-09 05:03:22.015497+00:00      Auto        Off  Enabled
# 22     2017-08-09 05:08:49.520110+00:00      Auto        Off  Enabled
# 23     2017-08-09 05:14:19.126314+00:00      Auto        Off  Enabled
# 24     2017-08-09 05:19:47.716507+00:00      Auto        Off  Enabled
# 25     2017-08-09 05:25:18.892705+00:00      Auto        Off  Enabled
# 26     2017-08-09 05:30:46.810339+00:00      Auto         On  Enabled
# 27     2017-08-09 05:36:15.048070+00:00      Auto         On  Enabled
# 28     2017-08-09 05:41:42.616044+00:00      Auto        Off  Enabled
# 29     2017-08-09 05:47:13.736839+00:00      Auto        Off  Enabled
# ...                                 ...       ...        ...      ...
# 23143  2017-11-07 00:24:54.583871+00:00      Auto         On  Enabled
# 23144  2017-11-07 00:30:33.001813+00:00      Auto         On  Enabled
# 23145  2017-11-07 00:36:04.432555+00:00      Auto        Off  Enabled
# 23146  2017-11-07 00:41:34.026211+00:00      Auto        Off  Enabled
# 23147  2017-11-07 00:47:05.147079+00:00      Auto        Off  Enabled
# 23148  2017-11-07 00:52:34.777186+00:00      Auto        Off  Enabled
# 23149  2017-11-07 00:58:44.108715+00:00      Auto        Off  Enabled
# 23150  2017-11-07 01:04:13.049097+00:00      Auto        Off  Enabled
# 23151  2017-11-07 01:09:40.785677+00:00      Auto        Off  Enabled
# 23152  2017-11-07 01:15:08.596940+00:00      Auto        Off  Enabled
# 23153  2017-11-07 01:20:37.152094+00:00      Auto        Off  Enabled
# 23154  2017-11-07 01:26:04.851110+00:00      Auto        Off  Enabled
# 23155  2017-11-07 01:31:35.368986+00:00      Auto        Off  Enabled
# 23156  2017-11-07 01:37:04.244156+00:00      Auto        Off  Enabled
# 23157  2017-11-07 01:42:33.346211+00:00      Auto        Off  Enabled
# 23158  2017-11-07 01:48:01.878604+00:00      Auto        Off  Enabled
# 23159  2017-11-07 01:53:37.825034+00:00      Auto        Off  Enabled
# 23160  2017-11-07 01:59:05.596926+00:00      Auto        Off  Enabled
# 23161  2017-11-07 02:04:35.367455+00:00      Auto        Off  Enabled
# 23162  2017-11-07 02:10:04.281536+00:00      Auto        Off  Enabled
# 23163  2017-11-07 02:15:34.411494+00:00      Auto        Off  Enabled
# 23164  2017-11-07 02:21:02.801937+00:00      Auto        Off  Enabled
# 23165  2017-11-07 02:26:31.034471+00:00      Auto        Off  Enabled
# 23166  2017-11-07 02:32:00.915772+00:00      Auto        Off  Enabled
# 23167  2017-11-07 02:37:28.825798+00:00      Auto        Off  Enabled
# 23168  2017-11-07 02:42:59.025156+00:00      Auto        Off  Enabled
# 23169  2017-11-07 02:48:31.736552+00:00      Auto        Off  Enabled
# 23170  2017-11-07 02:53:59.325175+00:00      Auto        Off  Enabled
# 23171  2017-11-07 02:59:27.025152+00:00      Auto        Off  Enabled
# 23172  2017-11-07 03:05:00.475983+00:00      Auto        Off  Enabled
#
#        ts1_t_cool  ts1_t_heat  ts1_temp ts1_tmode ts1_tstat_name ts1_tstate  \
# 0            75.0         NaN      75.0      Cool      1st Floor        Off
# 1            75.0         NaN      75.5      Cool      1st Floor        Off
# 2            75.0         NaN      75.5      Cool      1st Floor        Off
# 3            75.0         NaN      76.0      Cool      1st Floor       Cool
# 4            75.0         NaN      75.5      Cool      1st Floor       Cool
# 5            75.0         NaN      75.0      Cool      1st Floor        Off
# 6            75.0         NaN      75.0      Cool      1st Floor        Off
# 7            75.0         NaN      75.0      Cool      1st Floor        Off
# 8            75.0         NaN      75.5      Cool      1st Floor        Off
# 9            75.0         NaN      75.5      Cool      1st Floor        Off
# 10           75.0         NaN      75.5      Cool      1st Floor        Off
# 11           75.0         NaN      75.5      Cool      1st Floor        Off
# 12           75.0         NaN      76.0      Cool      1st Floor       Cool
# 13           75.0         NaN      75.0      Cool      1st Floor        Off
# 14           75.0         NaN      75.0      Cool      1st Floor        Off
# 15           75.0         NaN      75.0      Cool      1st Floor        Off
# 16           75.0         NaN      75.5      Cool      1st Floor        Off
# 17           75.0         NaN      75.5      Cool      1st Floor        Off
# 18           75.0         NaN      76.0      Cool      1st Floor       Cool
# 19           75.0         NaN      75.5      Cool      1st Floor       Cool
# 20           75.0         NaN      75.0      Cool      1st Floor        Off
# 21           75.0         NaN      75.0      Cool      1st Floor        Off
# 22           75.0         NaN      75.5      Cool      1st Floor        Off
# 23           75.0         NaN      75.5      Cool      1st Floor        Off
# 24           75.0         NaN      75.5      Cool      1st Floor        Off
# 25           75.0         NaN      75.5      Cool      1st Floor        Off
# 26           75.0         NaN      75.5      Cool      1st Floor       Cool
# 27           75.0         NaN      75.5      Cool      1st Floor       Cool
# 28           75.0         NaN      75.0      Cool      1st Floor        Off
# 29           75.0         NaN      75.0      Cool      1st Floor        Off
# ...           ...         ...       ...       ...            ...        ...
# 23143        75.0         NaN      75.5      Cool      1st Floor       Cool
# 23144        75.0         NaN      75.5      Cool      1st Floor       Cool
# 23145        75.0         NaN      74.5      Cool      1st Floor        Off
# 23146        75.0         NaN      74.5      Cool      1st Floor        Off
# 23147        75.0         NaN      74.5      Cool      1st Floor        Off
# 23148        75.0         NaN      74.5      Cool      1st Floor        Off
# 23149        75.0         NaN      74.5      Cool      1st Floor        Off
# 23150        75.0         NaN      74.5      Cool      1st Floor        Off
# 23151        75.0         NaN      74.5      Cool      1st Floor        Off
# 23152        75.0         NaN      74.5      Cool      1st Floor        Off
# 23153        75.0         NaN      74.5      Cool      1st Floor        Off
# 23154        75.0         NaN      75.0      Cool      1st Floor        Off
# 23155        75.0         NaN      75.0      Cool      1st Floor        Off
# 23156        75.0         NaN      75.0      Cool      1st Floor        Off
# 23157        75.0         NaN      75.0      Cool      1st Floor        Off
# 23158        75.0         NaN      75.0      Cool      1st Floor        Off
# 23159        75.0         NaN      75.0      Cool      1st Floor        Off
# 23160        75.0         NaN      75.0      Cool      1st Floor        Off
# 23161        75.0         NaN      75.0      Cool      1st Floor        Off
# 23162        75.0         NaN      75.0      Cool      1st Floor        Off
# 23163        75.0         NaN      75.0      Cool      1st Floor        Off
# 23164        75.0         NaN      75.0      Cool      1st Floor        Off
# 23165        75.0         NaN      75.0      Cool      1st Floor        Off
# 23166        75.0         NaN      75.0      Cool      1st Floor        Off
# 23167        75.0         NaN      75.0      Cool      1st Floor        Off
# 23168        75.0         NaN      75.0      Cool      1st Floor        Off
# 23169        75.0         NaN      75.0      Cool      1st Floor        Off
# 23170        75.0         NaN      75.0      Cool      1st Floor        Off
# 23171        75.0         NaN      74.5      Cool      1st Floor        Off
# 23172        75.0         NaN      74.5      Cool      1st Floor        Off
#
#             ...       wu_precip_1hr_in wu_precip_today_in  \
# 0           ...                 -999.0                0.0
# 1           ...                 -999.0                0.0
# 2           ...                 -999.0                0.0
# 3           ...                 -999.0                0.0
# 4           ...                 -999.0                0.0
# 5           ...                 -999.0                0.0
# 6           ...                 -999.0                0.0
# 7           ...                 -999.0                0.0
# 8           ...                 -999.0                0.0
# 9           ...                 -999.0                0.0
# 10          ...                 -999.0                0.0
# 11          ...                 -999.0                0.0
# 12          ...                 -999.0                0.0
# 13          ...                 -999.0                0.0
# 14          ...                 -999.0                0.0
# 15          ...                 -999.0                0.0
# 16          ...                 -999.0                0.0
# 17          ...                 -999.0                0.0
# 18          ...                 -999.0                0.0
# 19          ...                 -999.0                0.0
# 20          ...                 -999.0                0.0
# 21          ...                 -999.0                0.0
# 22          ...                 -999.0                0.0
# 23          ...                 -999.0                0.0
# 24          ...                 -999.0                0.0
# 25          ...                 -999.0                0.0
# 26          ...                 -999.0                0.0
# 27          ...                 -999.0                0.0
# 28          ...                 -999.0                0.0
# 29          ...                 -999.0                0.0
# ...         ...                    ...                ...
# 23143       ...                    0.0                0.0
# 23144       ...                    0.0                0.0
# 23145       ...                    0.0                0.0
# 23146       ...                    0.0                0.0
# 23147       ...                    0.0                0.0
# 23148       ...                    0.0                0.0
# 23149       ...                    0.0                0.0
# 23150       ...                    0.0                0.0
# 23151       ...                    0.0                0.0
# 23152       ...                    0.0                0.0
# 23153       ...                    0.0                0.0
# 23154       ...                    0.0                0.0
# 23155       ...                    0.0                0.0
# 23156       ...                    0.0                0.0
# 23157       ...                    0.0                0.0
# 23158       ...                    0.0                0.0
# 23159       ...                    0.0                0.0
# 23160       ...                    0.0                0.0
# 23161       ...                    0.0                0.0
# 23162       ...                    0.0                0.0
# 23163       ...                    0.0                0.0
# 23164       ...                    0.0                0.0
# 23165       ...                    0.0                0.0
# 23166       ...                    0.0                0.0
# 23167       ...                    0.0                0.0
# 23168       ...                    0.0                0.0
# 23169       ...                    0.0                0.0
# 23170       ...                    0.0                0.0
# 23171       ...                    0.0                0.0
# 23172       ...                    0.0                0.0
#
#       wu_relative_humidity  wu_station wu_temp_f     wu_weather  \
# 0                      61%   KTXLANTA3      81.6          Clear
# 1                      61%   KTXLANTA3      81.6          Clear
# 2                      62%   KTXLANTA3      81.4          Clear
# 3                      62%   KTXLANTA3      81.4          Clear
# 4                      63%   KTXLANTA3      81.2          Clear
# 5                      63%   KTXLANTA3      80.9          Clear
# 6                      63%   KTXLANTA3      80.9          Clear
# 7                      64%   KTXLANTA3      80.7          Clear
# 8                      64%   KTXLANTA3      80.5          Clear
# 9                      66%   KTXLANTA3      80.3          Clear
# 10                     65%   KTXLANTA3      80.2          Clear
# 11                     67%   KTXLANTA3      79.8          Clear
# 12                     68%   KTXLANTA3      79.6          Clear
# 13                     68%   KTXLANTA3      79.3          Clear
# 14                     68%   KTXLANTA3      79.1          Clear
# 15                     70%   KTXLANTA3      78.9          Clear
# 16                     71%   KTXLANTA3      78.9          Clear
# 17                     71%   KTXLANTA3      78.5          Clear
# 18                     71%   KTXLANTA3      78.4          Clear
# 19                     71%   KTXLANTA3      78.2          Clear
# 20                     70%   KTXLANTA3      78.2          Clear
# 21                     70%   KTXLANTA3      78.0          Clear
# 22                     70%   KTXLANTA3      78.0          Clear
# 23                     71%   KTXLANTA3      77.6          Clear
# 24                     71%   KTXLANTA3      77.6          Clear
# 25                     72%   KTXLANTA3      77.5          Clear
# 26                     73%   KTXLANTA3      77.3          Clear
# 27                     74%   KTXLANTA3      76.9          Clear
# 28                     74%   KTXLANTA3      76.7          Clear
# 29                     75%   KTXLANTA3      76.6          Clear
# ...                    ...         ...       ...            ...
# 23143                  81%  KTXARGYL24      62.1  Mostly Cloudy
# 23144                  82%  KTXARGYL24      61.7  Mostly Cloudy
# 23145                  83%  KTXARGYL24      61.2          Clear
# 23146                  83%  KTXARGYL24      60.8  Mostly Cloudy
# 23147                  83%  KTXARGYL24      60.4  Mostly Cloudy
# 23148                  83%  KTXARGYL24      60.3  Mostly Cloudy
# 23149                  84%  KTXARGYL24      59.9  Mostly Cloudy
# 23150                  84%  KTXARGYL24      59.7  Mostly Cloudy
# 23151                  84%  KTXARGYL24      59.5  Mostly Cloudy
# 23152                  85%  KTXARGYL24      59.4  Mostly Cloudy
# 23153                  85%  KTXARGYL24      59.2  Mostly Cloudy
# 23154                  86%  KTXARGYL24      59.2  Mostly Cloudy
# 23155                  86%  KTXARGYL24      59.0  Mostly Cloudy
# 23156                  87%  KTXARGYL24      58.8          Clear
# 23157                  87%  KTXARGYL24      58.8  Mostly Cloudy
# 23158                  87%  KTXARGYL24      58.6  Mostly Cloudy
# 23159                  88%  KTXARGYL24      58.5          Clear
# 23160                  88%  KTXARGYL24      58.3          Clear
# 23161                  88%  KTXARGYL24      58.3  Partly Cloudy
# 23162                  89%  KTXARGYL24      58.1          Clear
# 23163                  89%  KTXARGYL24      57.9  Mostly Cloudy
# 23164                  89%  KTXARGYL24      57.9          Clear
# 23165                  89%  KTXARGYL24      57.7  Mostly Cloudy
# 23166                  90%  KTXARGYL24      57.7  Mostly Cloudy
# 23167                  90%  KTXARGYL24      57.6  Mostly Cloudy
# 23168                  90%  KTXARGYL24      57.6  Mostly Cloudy
# 23169                  90%  KTXARGYL24      57.4  Mostly Cloudy
# 23170                  90%  KTXARGYL24      57.4  Mostly Cloudy
# 23171                  90%  KTXARGYL24      57.2  Mostly Cloudy
# 23172                  90%  KTXARGYL24      57.2  Mostly Cloudy
#
#       wu_wind_degrees wu_wind_gust_mph  wu_wind_mph  wu_windchill_f
# 0                  90              0.0          2.2             NaN
# 1                 112              0.0          1.1             NaN
# 2                  22              0.0          0.0             NaN
# 3                 202              0.0          0.0             NaN
# 4                  22              0.0          0.0             NaN
# 5                 292              0.0          0.0             NaN
# 6                  22              0.0          0.0             NaN
# 7                 112              0.0          1.7             NaN
# 8                 112              0.0          1.7             NaN
# 9                  22              0.0          0.0             NaN
# 10                270              0.0          0.0             NaN
# 11                270              0.0          0.0             NaN
# 12                180              0.0          0.0             NaN
# 13                157              0.0          2.7             NaN
# 14                 67              0.0          0.0             NaN
# 15                112              0.0          0.0             NaN
# 16                157              0.0          0.0             NaN
# 17                112              0.0          0.0             NaN
# 18                292              0.0          0.0             NaN
# 19                292              0.0          0.0             NaN
# 20                315              0.0          0.0             NaN
# 21                292              0.0          0.0             NaN
# 22                180              0.0          0.0             NaN
# 23                 45              0.0          1.7             NaN
# 24                112              0.0          0.0             NaN
# 25                337              0.0          0.0             NaN
# 26                315              0.0          0.0             NaN
# 27                225              0.0          0.0             NaN
# 28                202              0.0          0.0             NaN
# 29                315              0.0          0.0             NaN
# ...               ...              ...          ...             ...
# 23143             358              4.9          1.3             NaN
# 23144              53              0.0          0.0             NaN
# 23145             222              0.0          0.0             NaN
# 23146              15              2.5          0.9             NaN
# 23147               3              2.5          1.3             NaN
# 23148              20              4.9          3.4             NaN
# 23149             341              4.9          2.9             NaN
# 23150             335              0.0          0.0             NaN
# 23151             331              0.0          0.0             NaN
# 23152             350              2.5          0.9             NaN
# 23153               8              7.4          4.9             NaN
# 23154             359              4.9          2.5             NaN
# 23155             305              0.0          0.0             NaN
# 23156             358              2.5          0.4             NaN
# 23157             356              2.5          0.2             NaN
# 23158             313              0.0          0.0             NaN
# 23159             266              0.0          0.0             NaN
# 23160             352              2.5          0.2             NaN
# 23161             326              0.0          0.0             NaN
# 23162             307              0.0          0.0             NaN
# 23163             322              0.0          0.0             NaN
# 23164             349              0.0          0.0             NaN
# 23165             336              0.0          0.0             NaN
# 23166             329              0.0          0.0             NaN
# 23167              19              0.0          0.0             NaN
# 23168             358              0.0          0.0             NaN
# 23169             316              0.0          0.0             NaN
# 23170              31              0.0          0.0             NaN
# 23171               8              2.5          0.9             NaN
# 23172             348              2.5          1.3             NaN
#
# [23173 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['log_timestamp', 'ts1_fmode', 'ts1_fstate', 'ts1_hold', 'ts1_t_cool',
#        'ts1_t_heat', 'ts1_temp', 'ts1_tmode', 'ts1_tstat_name', 'ts1_tstate',
#        'ts2_fmode', 'ts2_fstate', 'ts2_hold', 'ts2_temp', 'ts2_tmode',
#        'ts2_tstat_name', 'ts2_tstate', 'tstat_id', 'wu_UV', 'wu_dewpoint_f',
#        'wu_heat_index_f', 'wu_precip_1hr_in', 'wu_precip_today_in',
#        'wu_relative_humidity', 'wu_station', 'wu_temp_f', 'wu_weather',
#        'wu_wind_degrees', 'wu_wind_gust_mph', 'wu_wind_mph', 'wu_windchill_f'],
#       dtype='object')

# %%
# drop unneeded columns
data.drop('ts1_fmode', axis=1, inplace=True)
data.drop('ts1_hold', axis=1, inplace=True)
data.drop('ts1_tstat_name', axis=1, inplace=True)

# %%
# create a new shifted _t_ column to represent the prior setpoint
data['ts1_t_cool_prior'] = data.ts1_t_cool.shift(-1)
#the target class/response variable is named class
data.loc[data.ts1_t_cool_prior > data.ts1_t_cool,'class'] = 1

# %%
data.T
# Out:
#                                                  0      \
# log_timestamp         2017-08-09 03:07:27.432848+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                          75.5
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     84
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               61%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         81.6
# wu_weather                                       Clear
# wu_wind_degrees                                     90
# wu_wind_gust_mph                                     0
# wu_wind_mph                                        2.2
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  1      \
# log_timestamp         2017-08-09 03:12:58.455624+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          75.5
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                          On
# ts2_hold                                       Enabled
# ts2_temp                                            76
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                        Cool
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     84
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               61%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         81.6
# wu_weather                                       Clear
# wu_wind_degrees                                    112
# wu_wind_gust_mph                                     0
# wu_wind_mph                                        1.1
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  2      \
# log_timestamp         2017-08-09 03:18:27.968084+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          75.5
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                          On
# ts2_hold                                       Enabled
# ts2_temp                                            76
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                        Cool
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     84
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               62%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         81.4
# wu_weather                                       Clear
# wu_wind_degrees                                     22
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  3      \
# log_timestamp         2017-08-09 03:23:57.327527+00:00
# ts1_fstate                                          On
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            76
# ts1_tmode                                         Cool
# ts1_tstate                                        Cool
# ts2_fmode                                         Auto
# ts2_fstate                                          On
# ts2_hold                                       Enabled
# ts2_temp                                            76
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                        Cool
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     84
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               62%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         81.4
# wu_weather                                       Clear
# wu_wind_degrees                                    202
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  4      \
# log_timestamp         2017-08-09 03:29:29.323964+00:00
# ts1_fstate                                          On
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          75.5
# ts1_tmode                                         Cool
# ts1_tstate                                        Cool
# ts2_fmode                                         Auto
# ts2_fstate                                          On
# ts2_hold                                       Enabled
# ts2_temp                                            76
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                        Cool
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     84
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               63%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         81.2
# wu_weather                                       Clear
# wu_wind_degrees                                     22
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  5      \
# log_timestamp         2017-08-09 03:34:57.039383+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                          On
# ts2_hold                                       Enabled
# ts2_temp                                          75.5
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                        Cool
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     83
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               63%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         80.9
# wu_weather                                       Clear
# wu_wind_degrees                                    292
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  6      \
# log_timestamp         2017-08-09 03:40:34.651107+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     83
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               63%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         80.9
# wu_weather                                       Clear
# wu_wind_degrees                                     22
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  7      \
# log_timestamp         2017-08-09 03:46:05.322617+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     83
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               64%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         80.7
# wu_weather                                       Clear
# wu_wind_degrees                                    112
# wu_wind_gust_mph                                     0
# wu_wind_mph                                        1.7
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  8      \
# log_timestamp         2017-08-09 03:51:39.227431+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          75.5
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                          75.5
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       67
# wu_heat_index_f                                     83
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               64%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         80.5
# wu_weather                                       Clear
# wu_wind_degrees                                    112
# wu_wind_gust_mph                                     0
# wu_wind_mph                                        1.7
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  9      \
# log_timestamp         2017-08-09 03:57:08.928282+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          75.5
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                          On
# ts2_hold                                       Enabled
# ts2_temp                                            76
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                        Cool
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                       68
# wu_heat_index_f                                     83
# wu_precip_1hr_in                                  -999
# wu_precip_today_in                                   0
# wu_relative_humidity                               66%
# wu_station                                   KTXLANTA3
# wu_temp_f                                         80.3
# wu_weather                                       Clear
# wu_wind_degrees                                     22
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                     ...                 \
# log_timestamp                       ...
# ts1_fstate                          ...
# ts1_t_cool                          ...
# ts1_t_heat                          ...
# ts1_temp                            ...
# ts1_tmode                           ...
# ts1_tstate                          ...
# ts2_fmode                           ...
# ts2_fstate                          ...
# ts2_hold                            ...
# ts2_temp                            ...
# ts2_tmode                           ...
# ts2_tstat_name                      ...
# ts2_tstate                          ...
# tstat_id                            ...
# wu_UV                               ...
# wu_dewpoint_f                       ...
# wu_heat_index_f                     ...
# wu_precip_1hr_in                    ...
# wu_precip_today_in                  ...
# wu_relative_humidity                ...
# wu_station                          ...
# wu_temp_f                           ...
# wu_weather                          ...
# wu_wind_degrees                     ...
# wu_wind_gust_mph                    ...
# wu_wind_mph                         ...
# wu_windchill_f                      ...
# ts1_t_cool_prior                    ...
# class                               ...
#
#                                                  23163  \
# log_timestamp         2017-11-07 02:15:34.411494+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                          74.5
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.7
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               89%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.9
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                    322
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23164  \
# log_timestamp         2017-11-07 02:21:02.801937+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                          74.5
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.7
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               89%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.9
# wu_weather                                       Clear
# wu_wind_degrees                                    349
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23165  \
# log_timestamp         2017-11-07 02:26:31.034471+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                          74.5
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.5
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               89%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.7
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                    336
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23166  \
# log_timestamp         2017-11-07 02:32:00.915772+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.9
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.7
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                    329
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23167  \
# log_timestamp         2017-11-07 02:37:28.825798+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.7
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.6
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                     19
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23168  \
# log_timestamp         2017-11-07 02:42:59.025156+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.7
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.6
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                    358
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23169  \
# log_timestamp         2017-11-07 02:48:31.736552+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.5
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.4
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                    316
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23170  \
# log_timestamp         2017-11-07 02:53:59.325175+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                            75
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.5
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.4
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                     31
# wu_wind_gust_mph                                     0
# wu_wind_mph                                          0
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23171  \
# log_timestamp         2017-11-07 02:59:27.025152+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          74.5
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.3
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.2
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                      8
# wu_wind_gust_mph                                   2.5
# wu_wind_mph                                        0.9
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                    75
# class                                                1
#
#                                                  23172
# log_timestamp         2017-11-07 03:05:00.475983+00:00
# ts1_fstate                                         Off
# ts1_t_cool                                          75
# ts1_t_heat                                         NaN
# ts1_temp                                          74.5
# ts1_tmode                                         Cool
# ts1_tstate                                         Off
# ts2_fmode                                         Auto
# ts2_fstate                                         Off
# ts2_hold                                       Enabled
# ts2_temp                                            75
# ts2_tmode                                         Cool
# ts2_tstat_name                               2nd Floor
# ts2_tstate                                         Off
# tstat_id                                      DEADBEEF
# wu_UV                                                0
# wu_dewpoint_f                                     54.3
# wu_heat_index_f                                    NaN
# wu_precip_1hr_in                                     0
# wu_precip_today_in                                   0
# wu_relative_humidity                               90%
# wu_station                                  KTXARGYL24
# wu_temp_f                                         57.2
# wu_weather                               Mostly Cloudy
# wu_wind_degrees                                    348
# wu_wind_gust_mph                                   2.5
# wu_wind_mph                                        1.3
# wu_windchill_f                                     NaN
# ts1_t_cool_prior                                   NaN
# class                                              NaN
#
# [30 rows x 23173 columns]

# %%
target_column_name = 'class'
target = data[target_column_name]
data.drop(target_column_name, axis=1, inplace=True)

# must change all features to numerical values
# https://github.com/rhiever/tpot/blob/master/tutorials/Titanic_Kaggle.ipynb

# extract time series attributes
# https://github.com/blue-yonder/tsfresh

# date and time 
# https://github.com/crsmithdev/arrow

# scikit-plot
# https://github.com/reiinakano/scikit-plot

X_train, X_test, y_train, y_test = train_test_split(data, target,
                                                    train_size=0.75, test_size=0.25)

# %%
tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))

# %%
tpot.export('tstat_pipeline.py')
